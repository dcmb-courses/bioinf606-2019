# %%
import pandas as pd

# %%
my_cereals = pd.read_table( './cereals.tsv' )

# %%
my_cereals
# Out:
#                 Name  Cups  Calories  Carbs  Fat  Fiber  Potassium  Protein  \
# 0         CapnCrunch  0.75       120   12.0    2    0.0         35        1
# 1         CocoaPuffs  1.00       110   12.0    1    0.0         55        1
# 2               Trix  1.00       110   13.0    1    0.0         25        1
# 3         AppleJacks  1.00       110   11.0    0    1.0         30        2
# 4           CornChex  1.00       110   22.0    0    0.0         25        2
# 5         CornFlakes  1.00       100   21.0    0    1.0         35        2
# 6          Nut&Honey  0.67       120   15.0    1    0.0         40        2
# 7             Smacks  0.75       110    9.0    1    1.0         40        2
# 8         MultiGrain  1.00       100   15.0    1    2.0         90        2
# 9        CracklinOat  0.50       110   10.0    3    4.0        160        3
# 10         GrapeNuts  0.25       110   17.0    0    3.0         90        3
# 11  HoneyNutCheerios  0.75       110   11.5    1    1.5         90        3
# 12        NutriGrain  0.67       140   21.0    2    3.0        130        3
# 13         Product19  1.00       100   20.0    0    1.0         45        3
# 14   TotalRaisinBran  1.00       140   15.0    1    4.0        230        3
# 15         WheatChex  0.67       100   17.0    1    3.0        115        3
# 16           Oatmeal  0.50       130   13.5    2    1.5        120        3
# 17              Life  0.67       100   12.0    2    2.0         95        4
# 18             Maypo  1.00       100   16.0    1    0.0         95        4
# 19        QuakerOats  0.50       100   14.0    1    2.0        110        4
# 20            Muesli  1.00       150   16.0    3    3.0        170        4
# 21          Cheerios  1.25       110   17.0    2    2.0        105        6
# 22          SpecialK  1.00       110   16.0    0    1.0         55        6
#
#     Sodium  Sugars
# 0      220      12
# 1      180      13
# 2      140      12
# 3      125      14
# 4      280       3
# 5      290       2
# 6      190       9
# 7       70      15
# 8      220       6
# 9      140       7
# 10     179       3
# 11     250      10
# 12     220       7
# 13     320       3
# 14     190      14
# 15     230       3
# 16     170      10
# 17     150       6
# 18       0       3
# 19     135       6
# 20     150      11
# 21     290       1
# 22     230       3

# %%
my_cereals.to_csv( './cereals_copy.csv' )

# %%
my_cereals.shape
# Out:
# (23, 10)

# %%
my_cereals.describe()
# Out:
#             Cups    Calories      Carbs        Fat      Fiber   Potassium  \
# count  23.000000   23.000000  23.000000  23.000000  23.000000   23.000000
# mean    0.823043  113.043478  15.043478   1.130435   1.565217   86.304348
# std     0.241010   14.281196   3.595809   0.919701   1.299513   53.069795
# min     0.250000  100.000000   9.000000   0.000000   0.000000   25.000000
# 25%     0.670000  100.000000  12.000000   0.500000   0.500000   40.000000
# 50%     1.000000  110.000000  15.000000   1.000000   1.500000   90.000000
# 75%     1.000000  115.000000  17.000000   2.000000   2.500000  112.500000
# max     1.250000  150.000000  22.000000   3.000000   4.000000  230.000000
#
#          Protein      Sodium     Sugars
# count  23.000000   23.000000  23.000000
# mean    2.913043  189.956522   7.521739
# std     1.345465   74.183727   4.470810
# min     1.000000    0.000000   1.000000
# 25%     2.000000  145.000000   3.000000
# 50%     3.000000  190.000000   7.000000
# 75%     3.500000  230.000000  11.500000
# max     6.000000  320.000000  15.000000

# %%
my_cereals.describe( )
# Out:
#             Cups    Calories      Carbs        Fat      Fiber   Potassium  \
# count  23.000000   23.000000  23.000000  23.000000  23.000000   23.000000
# mean    0.823043  113.043478  15.043478   1.130435   1.565217   86.304348
# std     0.241010   14.281196   3.595809   0.919701   1.299513   53.069795
# min     0.250000  100.000000   9.000000   0.000000   0.000000   25.000000
# 25%     0.670000  100.000000  12.000000   0.500000   0.500000   40.000000
# 50%     1.000000  110.000000  15.000000   1.000000   1.500000   90.000000
# 75%     1.000000  115.000000  17.000000   2.000000   2.500000  112.500000
# max     1.250000  150.000000  22.000000   3.000000   4.000000  230.000000
#
#          Protein      Sodium     Sugars
# count  23.000000   23.000000  23.000000
# mean    2.913043  189.956522   7.521739
# std     1.345465   74.183727   4.470810
# min     1.000000    0.000000   1.000000
# 25%     2.000000  145.000000   3.000000
# 50%     3.000000  190.000000   7.000000
# 75%     3.500000  230.000000  11.500000
# max     6.000000  320.000000  15.000000

# %%
my_cereals[ 'Potassium' ]
# Out:
# 0      35
# 1      55
# 2      25
# 3      30
# 4      25
# 5      35
# 6      40
# 7      40
# 8      90
# 9     160
# 10     90
# 11     90
# 12    130
# 13     45
# 14    230
# 15    115
# 16    120
# 17     95
# 18     95
# 19    110
# 20    170
# 21    105
# 22     55
# Name: Potassium, dtype: int64

# %%
my_cereals[ a_col_name ]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-334b435f272e> in <module>()
# ----> 1 my_cereals[ a_col_name ]
#
# NameError: name 'a_col_name' is not defined

# %%
a_col_name = 'Sodium'

# %%
my_cereals[ a_col_name ]
# Out:
# 0     220
# 1     180
# 2     140
# 3     125
# 4     280
# 5     290
# 6     190
# 7      70
# 8     220
# 9     140
# 10    179
# 11    250
# 12    220
# 13    320
# 14    190
# 15    230
# 16    170
# 17    150
# 18      0
# 19    135
# 20    150
# 21    290
# 22    230
# Name: Sodium, dtype: int64

# %%
my_cereals[ ['Calories','Sodium'] ]
# Out:
#     Calories  Sodium
# 0        120     220
# 1        110     180
# 2        110     140
# 3        110     125
# 4        110     280
# 5        100     290
# 6        120     190
# 7        110      70
# 8        100     220
# 9        110     140
# 10       110     179
# 11       110     250
# 12       140     220
# 13       100     320
# 14       140     190
# 15       100     230
# 16       130     170
# 17       100     150
# 18       100       0
# 19       100     135
# 20       150     150
# 21       110     290
# 22       110     230

# %%
my_cereals
# Out:
#                 Name  Cups  Calories  Carbs  Fat  Fiber  Potassium  Protein  \
# 0         CapnCrunch  0.75       120   12.0    2    0.0         35        1
# 1         CocoaPuffs  1.00       110   12.0    1    0.0         55        1
# 2               Trix  1.00       110   13.0    1    0.0         25        1
# 3         AppleJacks  1.00       110   11.0    0    1.0         30        2
# 4           CornChex  1.00       110   22.0    0    0.0         25        2
# 5         CornFlakes  1.00       100   21.0    0    1.0         35        2
# 6          Nut&Honey  0.67       120   15.0    1    0.0         40        2
# 7             Smacks  0.75       110    9.0    1    1.0         40        2
# 8         MultiGrain  1.00       100   15.0    1    2.0         90        2
# 9        CracklinOat  0.50       110   10.0    3    4.0        160        3
# 10         GrapeNuts  0.25       110   17.0    0    3.0         90        3
# 11  HoneyNutCheerios  0.75       110   11.5    1    1.5         90        3
# 12        NutriGrain  0.67       140   21.0    2    3.0        130        3
# 13         Product19  1.00       100   20.0    0    1.0         45        3
# 14   TotalRaisinBran  1.00       140   15.0    1    4.0        230        3
# 15         WheatChex  0.67       100   17.0    1    3.0        115        3
# 16           Oatmeal  0.50       130   13.5    2    1.5        120        3
# 17              Life  0.67       100   12.0    2    2.0         95        4
# 18             Maypo  1.00       100   16.0    1    0.0         95        4
# 19        QuakerOats  0.50       100   14.0    1    2.0        110        4
# 20            Muesli  1.00       150   16.0    3    3.0        170        4
# 21          Cheerios  1.25       110   17.0    2    2.0        105        6
# 22          SpecialK  1.00       110   16.0    0    1.0         55        6
#
#     Sodium  Sugars
# 0      220      12
# 1      180      13
# 2      140      12
# 3      125      14
# 4      280       3
# 5      290       2
# 6      190       9
# 7       70      15
# 8      220       6
# 9      140       7
# 10     179       3
# 11     250      10
# 12     220       7
# 13     320       3
# 14     190      14
# 15     230       3
# 16     170      10
# 17     150       6
# 18       0       3
# 19     135       6
# 20     150      11
# 21     290       1
# 22     230       3

# %%
my_cereals.iloc[15]
# Out:
# Name         WheatChex
# Cups              0.67
# Calories           100
# Carbs               17
# Fat                  1
# Fiber                3
# Potassium          115
# Protein              3
# Sodium             230
# Sugars               3
# Name: 15, dtype: object

# %%
my_cereals
# Out:
#                 Name  Cups  Calories  Carbs  Fat  Fiber  Potassium  Protein  \
# 0         CapnCrunch  0.75       120   12.0    2    0.0         35        1
# 1         CocoaPuffs  1.00       110   12.0    1    0.0         55        1
# 2               Trix  1.00       110   13.0    1    0.0         25        1
# 3         AppleJacks  1.00       110   11.0    0    1.0         30        2
# 4           CornChex  1.00       110   22.0    0    0.0         25        2
# 5         CornFlakes  1.00       100   21.0    0    1.0         35        2
# 6          Nut&Honey  0.67       120   15.0    1    0.0         40        2
# 7             Smacks  0.75       110    9.0    1    1.0         40        2
# 8         MultiGrain  1.00       100   15.0    1    2.0         90        2
# 9        CracklinOat  0.50       110   10.0    3    4.0        160        3
# 10         GrapeNuts  0.25       110   17.0    0    3.0         90        3
# 11  HoneyNutCheerios  0.75       110   11.5    1    1.5         90        3
# 12        NutriGrain  0.67       140   21.0    2    3.0        130        3
# 13         Product19  1.00       100   20.0    0    1.0         45        3
# 14   TotalRaisinBran  1.00       140   15.0    1    4.0        230        3
# 15         WheatChex  0.67       100   17.0    1    3.0        115        3
# 16           Oatmeal  0.50       130   13.5    2    1.5        120        3
# 17              Life  0.67       100   12.0    2    2.0         95        4
# 18             Maypo  1.00       100   16.0    1    0.0         95        4
# 19        QuakerOats  0.50       100   14.0    1    2.0        110        4
# 20            Muesli  1.00       150   16.0    3    3.0        170        4
# 21          Cheerios  1.25       110   17.0    2    2.0        105        6
# 22          SpecialK  1.00       110   16.0    0    1.0         55        6
#
#     Sodium  Sugars
# 0      220      12
# 1      180      13
# 2      140      12
# 3      125      14
# 4      280       3
# 5      290       2
# 6      190       9
# 7       70      15
# 8      220       6
# 9      140       7
# 10     179       3
# 11     250      10
# 12     220       7
# 13     320       3
# 14     190      14
# 15     230       3
# 16     170      10
# 17     150       6
# 18       0       3
# 19     135       6
# 20     150      11
# 21     290       1
# 22     230       3

# %%
my_cereals2 = my_cereals.set_index( 'Name' )

# %%
my_cereals2
# Out:
#                   Cups  Calories  Carbs  Fat  Fiber  Potassium  Protein  \
# Name
# CapnCrunch        0.75       120   12.0    2    0.0         35        1
# CocoaPuffs        1.00       110   12.0    1    0.0         55        1
# Trix              1.00       110   13.0    1    0.0         25        1
# AppleJacks        1.00       110   11.0    0    1.0         30        2
# CornChex          1.00       110   22.0    0    0.0         25        2
# CornFlakes        1.00       100   21.0    0    1.0         35        2
# Nut&Honey         0.67       120   15.0    1    0.0         40        2
# Smacks            0.75       110    9.0    1    1.0         40        2
# MultiGrain        1.00       100   15.0    1    2.0         90        2
# CracklinOat       0.50       110   10.0    3    4.0        160        3
# GrapeNuts         0.25       110   17.0    0    3.0         90        3
# HoneyNutCheerios  0.75       110   11.5    1    1.5         90        3
# NutriGrain        0.67       140   21.0    2    3.0        130        3
# Product19         1.00       100   20.0    0    1.0         45        3
# TotalRaisinBran   1.00       140   15.0    1    4.0        230        3
# WheatChex         0.67       100   17.0    1    3.0        115        3
# Oatmeal           0.50       130   13.5    2    1.5        120        3
# Life              0.67       100   12.0    2    2.0         95        4
# Maypo             1.00       100   16.0    1    0.0         95        4
# QuakerOats        0.50       100   14.0    1    2.0        110        4
# Muesli            1.00       150   16.0    3    3.0        170        4
# Cheerios          1.25       110   17.0    2    2.0        105        6
# SpecialK          1.00       110   16.0    0    1.0         55        6
#
#                   Sodium  Sugars
# Name
# CapnCrunch           220      12
# CocoaPuffs           180      13
# Trix                 140      12
# AppleJacks           125      14
# CornChex             280       3
# CornFlakes           290       2
# Nut&Honey            190       9
# Smacks                70      15
# MultiGrain           220       6
# CracklinOat          140       7
# GrapeNuts            179       3
# HoneyNutCheerios     250      10
# NutriGrain           220       7
# Product19            320       3
# TotalRaisinBran      190      14
# WheatChex            230       3
# Oatmeal              170      10
# Life                 150       6
# Maypo                  0       3
# QuakerOats           135       6
# Muesli               150      11
# Cheerios             290       1
# SpecialK             230       3

# %%
my_cereals2.loc[ 'WheatChex' ]
# Out:
# Cups           0.67
# Calories     100.00
# Carbs         17.00
# Fat            1.00
# Fiber          3.00
# Potassium    115.00
# Protein        3.00
# Sodium       230.00
# Sugars         3.00
# Name: WheatChex, dtype: float64

# %%
my_cereals2.loc[ 'WheatChecks' ]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/kitzmanj/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1394                 if key not in ax:
# -> 1395                     error()
#    1396             except TypeError as e:
#
# /Users/kitzmanj/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py in error()
#    1389                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1390                                (key, self.obj._get_axis_name(axis)))
#    1391
#
# KeyError: 'the label [WheatChecks] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-34157edaca95> in <module>()
# ----> 1 my_cereals2.loc[ 'WheatChecks' ]
#
# /Users/kitzmanj/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1294             return self._getitem_tuple(key)
#    1295         else:
# -> 1296             return self._getitem_axis(key, axis=0)
#    1297
#    1298     def _getitem_axis(self, key, axis=0):
#
# /Users/kitzmanj/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1464
#    1465         # fall thru to straight lookup
# -> 1466         self._has_valid_type(key, axis)
#    1467         return self._get_label(key, axis=axis)
#    1468
#
# /Users/kitzmanj/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1401                 raise
#    1402             except:
# -> 1403                 error()
#    1404
#    1405         return True
#
# /Users/kitzmanj/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py in error()
#    1388                                     "key")
#    1389                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1390                                (key, self.obj._get_axis_name(axis)))
#    1391
#    1392             try:
#
# KeyError: 'the label [WheatChecks] is not in the [index]'

# %%
'WheatChex' in my_cereals2.index
# Out:
# True

# %%
'WheatChecks' in my_cereals2.index
# Out:
# False

# %%
my_cereals2['Calories'] < 110
# Out:
# Name
# CapnCrunch          False
# CocoaPuffs          False
# Trix                False
# AppleJacks          False
# CornChex            False
# CornFlakes           True
# Nut&Honey           False
# Smacks              False
# MultiGrain           True
# CracklinOat         False
# GrapeNuts           False
# HoneyNutCheerios    False
# NutriGrain          False
# Product19            True
# TotalRaisinBran     False
# WheatChex            True
# Oatmeal             False
# Life                 True
# Maypo                True
# QuakerOats           True
# Muesli              False
# Cheerios            False
# SpecialK            False
# Name: Calories, dtype: bool

# %%
my_cereals2.loc[ my_cereals2['Calories'] < 110 ]
# Out:
#             Cups  Calories  Carbs  Fat  Fiber  Potassium  Protein  Sodium  \
# Name
# CornFlakes  1.00       100   21.0    0    1.0         35        2     290
# MultiGrain  1.00       100   15.0    1    2.0         90        2     220
# Product19   1.00       100   20.0    0    1.0         45        3     320
# WheatChex   0.67       100   17.0    1    3.0        115        3     230
# Life        0.67       100   12.0    2    2.0         95        4     150
# Maypo       1.00       100   16.0    1    0.0         95        4       0
# QuakerOats  0.50       100   14.0    1    2.0        110        4     135
#
#             Sugars
# Name
# CornFlakes       2
# MultiGrain       6
# Product19        3
# WheatChex        3
# Life             6
# Maypo            3
# QuakerOats       6

# %%
my_cereals2.columns
# Out:
# Index(['Cups', 'Calories', 'Carbs', 'Fat', 'Fiber', 'Potassium', 'Protein',
#        'Sodium', 'Sugars'],
#       dtype='object')

# %%
my_cereals2[ my_cereals2.columns[:3] ]
# Out:
#                   Cups  Calories  Carbs
# Name
# CapnCrunch        0.75       120   12.0
# CocoaPuffs        1.00       110   12.0
# Trix              1.00       110   13.0
# AppleJacks        1.00       110   11.0
# CornChex          1.00       110   22.0
# CornFlakes        1.00       100   21.0
# Nut&Honey         0.67       120   15.0
# Smacks            0.75       110    9.0
# MultiGrain        1.00       100   15.0
# CracklinOat       0.50       110   10.0
# GrapeNuts         0.25       110   17.0
# HoneyNutCheerios  0.75       110   11.5
# NutriGrain        0.67       140   21.0
# Product19         1.00       100   20.0
# TotalRaisinBran   1.00       140   15.0
# WheatChex         0.67       100   17.0
# Oatmeal           0.50       130   13.5
# Life              0.67       100   12.0
# Maypo             1.00       100   16.0
# QuakerOats        0.50       100   14.0
# Muesli            1.00       150   16.0
# Cheerios          1.25       110   17.0
# SpecialK          1.00       110   16.0

# %%
my_cereals2['delicious']=True

# %%
my_cereals2
# Out:
#                   Cups  Calories  Carbs  Fat  Fiber  Potassium  Protein  \
# Name
# CapnCrunch        0.75       120   12.0    2    0.0         35        1
# CocoaPuffs        1.00       110   12.0    1    0.0         55        1
# Trix              1.00       110   13.0    1    0.0         25        1
# AppleJacks        1.00       110   11.0    0    1.0         30        2
# CornChex          1.00       110   22.0    0    0.0         25        2
# CornFlakes        1.00       100   21.0    0    1.0         35        2
# Nut&Honey         0.67       120   15.0    1    0.0         40        2
# Smacks            0.75       110    9.0    1    1.0         40        2
# MultiGrain        1.00       100   15.0    1    2.0         90        2
# CracklinOat       0.50       110   10.0    3    4.0        160        3
# GrapeNuts         0.25       110   17.0    0    3.0         90        3
# HoneyNutCheerios  0.75       110   11.5    1    1.5         90        3
# NutriGrain        0.67       140   21.0    2    3.0        130        3
# Product19         1.00       100   20.0    0    1.0         45        3
# TotalRaisinBran   1.00       140   15.0    1    4.0        230        3
# WheatChex         0.67       100   17.0    1    3.0        115        3
# Oatmeal           0.50       130   13.5    2    1.5        120        3
# Life              0.67       100   12.0    2    2.0         95        4
# Maypo             1.00       100   16.0    1    0.0         95        4
# QuakerOats        0.50       100   14.0    1    2.0        110        4
# Muesli            1.00       150   16.0    3    3.0        170        4
# Cheerios          1.25       110   17.0    2    2.0        105        6
# SpecialK          1.00       110   16.0    0    1.0         55        6
#
#                   Sodium  Sugars delicious
# Name
# CapnCrunch           220      12      True
# CocoaPuffs           180      13      True
# Trix                 140      12      True
# AppleJacks           125      14      True
# CornChex             280       3      True
# CornFlakes           290       2      True
# Nut&Honey            190       9      True
# Smacks                70      15      True
# MultiGrain           220       6      True
# CracklinOat          140       7      True
# GrapeNuts            179       3      True
# HoneyNutCheerios     250      10      True
# NutriGrain           220       7      True
# Product19            320       3      True
# TotalRaisinBran      190      14      True
# WheatChex            230       3      True
# Oatmeal              170      10      True
# Life                 150       6      True
# Maypo                  0       3      True
# QuakerOats           135       6      True
# Muesli               150      11      True
# Cheerios             290       1      True
# SpecialK             230       3      True

# %%
my_cereals2['low_cal'] = my_cereals2['Calories']<110

# %%
my_cereals2
# Out:
#                   Cups  Calories  Carbs  Fat  Fiber  Potassium  Protein  \
# Name
# CapnCrunch        0.75       120   12.0    2    0.0         35        1
# CocoaPuffs        1.00       110   12.0    1    0.0         55        1
# Trix              1.00       110   13.0    1    0.0         25        1
# AppleJacks        1.00       110   11.0    0    1.0         30        2
# CornChex          1.00       110   22.0    0    0.0         25        2
# CornFlakes        1.00       100   21.0    0    1.0         35        2
# Nut&Honey         0.67       120   15.0    1    0.0         40        2
# Smacks            0.75       110    9.0    1    1.0         40        2
# MultiGrain        1.00       100   15.0    1    2.0         90        2
# CracklinOat       0.50       110   10.0    3    4.0        160        3
# GrapeNuts         0.25       110   17.0    0    3.0         90        3
# HoneyNutCheerios  0.75       110   11.5    1    1.5         90        3
# NutriGrain        0.67       140   21.0    2    3.0        130        3
# Product19         1.00       100   20.0    0    1.0         45        3
# TotalRaisinBran   1.00       140   15.0    1    4.0        230        3
# WheatChex         0.67       100   17.0    1    3.0        115        3
# Oatmeal           0.50       130   13.5    2    1.5        120        3
# Life              0.67       100   12.0    2    2.0         95        4
# Maypo             1.00       100   16.0    1    0.0         95        4
# QuakerOats        0.50       100   14.0    1    2.0        110        4
# Muesli            1.00       150   16.0    3    3.0        170        4
# Cheerios          1.25       110   17.0    2    2.0        105        6
# SpecialK          1.00       110   16.0    0    1.0         55        6
#
#                   Sodium  Sugars delicious low_cal
# Name
# CapnCrunch           220      12      True   False
# CocoaPuffs           180      13      True   False
# Trix                 140      12      True   False
# AppleJacks           125      14      True   False
# CornChex             280       3      True   False
# CornFlakes           290       2      True    True
# Nut&Honey            190       9      True   False
# Smacks                70      15      True   False
# MultiGrain           220       6      True    True
# CracklinOat          140       7      True   False
# GrapeNuts            179       3      True   False
# HoneyNutCheerios     250      10      True   False
# NutriGrain           220       7      True   False
# Product19            320       3      True    True
# TotalRaisinBran      190      14      True   False
# WheatChex            230       3      True    True
# Oatmeal              170      10      True   False
# Life                 150       6      True    True
# Maypo                  0       3      True    True
# QuakerOats           135       6      True    True
# Muesli               150      11      True   False
# Cheerios             290       1      True   False
# SpecialK             230       3      True   False

# %%
cereals_by_cal = my_cereals2.groupby('low_cal')

# %%
cereals_by_cal['Sodium'].agg('mean')
# Out:
# low_cal
# False    189.000000
# True     192.142857
# Name: Sodium, dtype: float64

# %%
cereals_by_cal.agg('mean')
# Out:
#              Cups  Calories      Carbs       Fat     Fiber  Potassium  \
# low_cal
# False    0.818125    118.75  14.437500  1.250000  1.562500  87.500000
# True     0.834286    100.00  16.428571  0.857143  1.571429  83.571429
#
#           Protein      Sodium    Sugars delicious
# low_cal
# False    2.812500  189.000000  9.000000      True
# True     3.142857  192.142857  4.142857      True

# %%
# %pylab inline
# this does some imports for us
# including
# import numpy as np
# import pylab as plt
#
# and it tells the notebook to show us plots as we make them (as opposed to saving them out to files)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
my_cereals2.plot( 'Carbs', 'Fat', kind='scatter' )
